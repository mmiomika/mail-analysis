# %%
import pandas as pd
import numpy as np

from datetime import datetime
import time

from collections import defaultdict
from collections import Counter
from collections import OrderedDict

import matplotlib.pyplot as plt
from matplotlib import dates
from scipy.stats import powerlaw

# %matplotlib inline

from math import log

import sys

# %%
def emails_days(df):
    days = [str_to_day(s) for s in df['Timestamp'].tolist()]
    return normalize_days(days)

def str_to_day(s):
    return time.mktime(datetime.strptime(s, '%d.%m.%Y %H:%M:%S').timetuple()) // (24 * 60 * 60)

def normalize_days(days):
    min_ = min(days)
    days = [int(ts - min_) for ts in days]
    return days

# %%
df = pd.read_csv("MessageTracking-anon.csv", error_bad_lines=False)

# %%
df.columns = ['Timestamp', 'Sender', 'Recipients', 'MessageSubject', 'InternalMessageId', 'clientid','ConnectorId', 
              'RecipientStatus', 'TotalBytes', 'RecipientCount', 'RelatedRecipientAddress', 
              'Reference', 'ReturnPath', 'MessageInfo', 'EventId', 'MessageId']

# %%
spamers = ['5c316fcd8e442c933d6597a609a5c3ab@62144c8c8c29ab916720cf6480112f77']


def delete(source, spamersAll):
    for spamer in spamersAll:
        source = source.replace(spamer, "")
    return source.strip()

df = df[df['MessageSubject'] != 'EMPTY']
df = df[df['Recipients'] != '']
df.loc[:, 'Recipients'] = [delete(recipient, spamers) for recipient in df['Recipients']]
df = df[[sender not in spamers for sender in df['Sender']]]
df = df[df['Recipients'] != '']

df.loc[:, 'Day'] = emails_days(df)

df_receive = df[df['EventId'] == 'RECEIVE']
df_deliver = df[df['EventId'] == 'DELIVER']

# %%
df_deliver.head()
# Out:
#               Timestamp                                             Sender  \
# 2   19.05.2016 02:03:19  99f912969da4765194bdbd392118e7f9@8d192ad005fa7...
# 6   19.05.2016 04:15:09  cbdf58e49d76188667a090f830325853@8d192ad005fa7...
# 7   19.05.2016 04:15:09  cbdf58e49d76188667a090f830325853@8d192ad005fa7...
# 12  19.05.2016 05:00:21  64f7365aff86ad15736336caa208bfaa@8d192ad005fa7...
# 15  19.05.2016 07:00:02  9a07926a0c2034df187d91cd270f91ee@8d192ad005fa7...
#
#                                            Recipients  \
# 2   84005a05f147f9afe926d50b09aa8039@8d192ad005fa7...
# 6   0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa7...
# 7   8517f5421476d59f05c4a434d3f12d72@8d192ad005fa7...
# 12  84005a05f147f9afe926d50b09aa8039@8d192ad005fa7...
# 15  84005a05f147f9afe926d50b09aa8039@8d192ad005fa7...
#
#                       MessageSubject  InternalMessageId  clientid ConnectorId  \
# 2   55d3697c4c4b03bfb6d60ebae7e6c425             858559       NaN         NaN
# 6   55e8a08305b7cd6e53db98494910f990             858592       NaN         NaN
# 7   55e8a08305b7cd6e53db98494910f990             858594       NaN         NaN
# 12  baf42bc451ea2c301cbbde532a849c53             858604       NaN         NaN
# 15  d4b182a90cabae58d14e3996a8cde1fa             858681       NaN         NaN
#
#         RecipientStatus  TotalBytes  RecipientCount RelatedRecipientAddress  \
# 2                   NaN      390654               1                     NaN
# 6                   NaN      243317               2                     NaN
# 7                   NaN      243361               5                     NaN
# 12  Veeam    D_IT Other        2022               6                     NaN
# 15                  NaN       36555               1                     NaN
#
#    Reference                                         ReturnPath  \
# 2        NaN  99f912969da4765194bdbd392118e7f9@8d192ad005fa7...
# 6        NaN  cbdf58e49d76188667a090f830325853@8d192ad005fa7...
# 7        NaN  cbdf58e49d76188667a090f830325853@8d192ad005fa7...
# 12       NaN  64f7365aff86ad15736336caa208bfaa@8d192ad005fa7...
# 15       NaN  84005a05f147f9afe926d50b09aa8039@8d192ad005fa7...
#
#                                           MessageInfo  EventId  \
# 2   2016-05-19T00:03:19.201Z;SRV=SRVEX01.slb-bank....  DELIVER
# 6   2016-05-19T02:15:08.536Z;SRV=SRVEX01.slb-bank....  DELIVER
# 7   2016-05-19T02:15:08.536Z;SRV=SRVEX01.slb-bank....  DELIVER
# 12  2016-05-19T03:00:20.759Z;SRV=SRVEX01.slb-bank....  DELIVER
# 15  2016-05-19T05:00:01.647Z;SRV=SRVEX01.slb-bank....  DELIVER
#
#                                             MessageId  Day
# 2   <04d61213-32bb-44e1-8655-86a714ac0b75@SRVEX01....    0
# 6   <c62b74b5e8734b65a1e97d4b35e57dec@SRVEX01.slb-...    1
# 7   <c62b74b5e8734b65a1e97d4b35e57dec@SRVEX01.slb-...    1
# 12  <337bd3cc-80c3-43dc-a470-418f9a696d38@SRVEX01....    1
# 15  <43b95032-a174-4df4-b25e-b710be4be24d@SRVEX01....    1

# %%
def distribution(objects):
    result_distribution = defaultdict(int)
    for obj in objects:
        result_distribution[obj] += 1
    return result_distribution
        
def cCDF(distribution):
    result = defaultdict(int)
    sum_ = 0
    
    total_sum = float(sum(distribution.values()))
    
    for key in sorted(distribution.keys()):
        sum_ += distribution[key]
        result[key] = 1 - sum_ / total_sum 

    return result

# %%
def get_senders(df):
    return [sender for sender in df['Sender']]

def get_recipients(df):
    return reduce(lambda a, x: a + x, df['Recipients'].map(lambda x: x.split()).tolist(), [])

# %% [markdown]
# ## Размеры письма

# %%
mail_distr = defaultdict(int)
scale = 200

for size in df_receive['TotalBytes']:
    mail_distr[(size // scale) * scale] += 1

# %%
plt.loglog(mail_distr.keys(), mail_distr.values(), 'bo')
plt.ylabel(u"Количество писем")
plt.xlabel(u"Размер писем")
plt.grid(True)
plt.show()

# %%
ccdf_ = cCDF(mail_distr)

# %%
plt.loglog(ccdf_.keys(), ccdf_.values(), 'bo')
plt.ylabel(u"CCDF")
plt.xlabel(u"Размер писем")
plt.grid(True)
plt.show()

# %% [markdown]
# Гистограмма размера электронной имеет пики около 3 КБ и 10 КБ. CCDF размера электронной почты имеет вид степенного распределения, диапазон от 10 КБ до 3 МБ. Большинство писем имеют маленькие размеры, но и немало писем с большим размером

# %%
def MailSizes(df):
    result = defaultdict(list)
    for index, row in df.iterrows():
        sender = row['Sender']
        size = row['TotalBytes']
        result[sender].append(size)
    return result

mailSizes = MailSizes(df_receive)

# %%
len(mailSizes)
# Out:
# 123

# %%
mailSizes_loc = []
mailSizes_scale = []
for k, v in mailSizes.items():
    results = powerlaw.fit(mailSizes.get(k))
    mailSizes_loc.append(results[0])
    mailSizes_scale.append(results[1])

# %%
mailSizesMean = {}
for sender in mailSizes.keys():
    mailSizesMean[sender] = np.median(mailSizes[sender])

# %%
mailSizesCcdf = cCDF(Counter(filter(lambda x: x < 150000, mailSizesMean.values())))

plt.ylabel(u'Процент людей с данным количеством получателей')
plt.xlabel(u'Размер писем')
plt.grid()
plt.plot(mailSizesCcdf.keys(), mailSizesCcdf.values(), 'bo')
plt.show()

# %% [markdown]
# В среднем отправляют 18Кб данных. ~10% отправляют 6Кб данных или меньше, также ~10% отправляют больше 50Кб.

# %% [markdown]
# ##  Время ответа

# %%
def ReactionTime(df):
    result = defaultdict(list)
    
    subjects = getThreadsSubjects(df)
    for subject in subjects:
        messages = threadMessages(df, subject)
        timestamps = pd.to_datetime(messages['Timestamp'], format='%d.%m.%Y %H:%M:%S')
        senders = messages['Sender']
    
        delays = senderDelays(timestamps, senders)
        for delay in delays:
            result[delay[0]].append(delay[1])
        
    return result

def getThreadsSubjects(df):
    return list(set(df['MessageSubject']))

def threadMessages(df, subject):
    return df[df['MessageSubject'] == subject]

def senderDelays(timestamps, senders):
    senders = senders[1:]
    delays = map(lambda pair: (pair[0] - pair[1]).seconds, zip(timestamps.iloc[1:], timestamps.iloc[:-1]))
    return zip(senders, delays)

senderDelays = ReactionTime(df_receive)

# %%
senderDelays_loc = []
senderDelays_scale = []

for k, v in senderDelays.items():
    results = powerlaw.fit(senderDelays.get(k))
    senderDelays_loc.append(results[0])
    senderDelays_scale.append(results[1])

# %%
meanSenderDelays = {}
for sender in senderDelays.keys():
    meanSenderDelays[sender] = np.median(senderDelays[sender])

# %%
delaysCcdf = cCDF(Counter(filter(lambda delay: delay < 10000, meanSenderDelays.values())))

plt.ylabel(u'Процент отвечающих дольше данного времени')
plt.xlabel(u'Время ответа (сек)')
plt.grid()
plt.plot(delaysCcdf.keys(), delaysCcdf.values(), 'bo')
plt.show()

# %% [markdown]
# Около 10% людей отвечают в течение часа. Половина пользователей в среднем отвечают в течение 20 минут. Около 20% людей, отвечающих в течение  40 минут после получения письма.

# %% [markdown]
# ## Длина треда в момент отправки письма

# %%
def ThreadSizes(df):
    result = defaultdict(list)
    threads = findThreads(df)
    for thread in findThreads(df):
        indexes = sendIndexesInThread(thread)
        for userIndex in indexes:
            result[userIndex[0]].append(userIndex[1])
    return result

def findThreads(df):
    subjects = getThreadsSubjects(df)
    return [threadMessages(df, subject) for subject in subjects]

def sendIndexesInThread(thread):
    indexes = range(thread.shape[0])
    return zip(thread['Sender'], indexes)
    

PositionInTheThread = ThreadSizes(df_receive)

# %%
PositionInTheThread_loc = []
PositionInTheThread_scale = []
for k, v in PositionInTheThread.items():
    results = powerlaw.fit(PositionInTheThread.get(k))
    PositionInTheThread_loc.append(results[0])
    PositionInTheThread_scale.append(results[1])

# %%
meanPositionInTheThread = {}
for sender in PositionInTheThread.keys():
    meanPositionInTheThread[sender] = np.mean(PositionInTheThread[sender])

positionsCcdf = cCDF(Counter(filter(lambda pos: pos < 30, meanPositionInTheThread.values())))

plt.ylabel(u'Процент людей, растягивающих тред до данного размера')
plt.xlabel(u'средняя позиция в треде')
plt.grid()
plt.plot(positionsCcdf.keys(), positionsCcdf.values(), 'bo')
plt.show()

# %% [markdown]
# ~50% стараются писать в треды не больше 3-4 сообщений. ~20% людей пишут в треды с 5 и больше сообщениями.

# %% [markdown]
# ## Количество получателей в письме

# %%
def RecipientNumber(df):
    result = defaultdict(list)
    for index, row in df.iterrows():
        sender = row['Sender']
        count = row['RecipientCount']
        result[sender].append(count)
    return result

recipientNumberInMails = RecipientNumber(df_receive)

# %%
recipientNumberInMails_loc = []
recipientNumberInMails_scale = []
for k, v in recipientNumberInMails.items():
    results = powerlaw.fit(recipientNumberInMails.get(k))
    recipientNumberInMails_loc.append(results[0])
    recipientNumberInMails_scale.append(results[1])

# %%
meanrecipientNumberInMails = {}
for sender in recipientNumberInMails.keys():
    meanrecipientNumberInMails[sender] = np.mean(recipientNumberInMails[sender])

recipientsCcdf = cCDF(Counter(filter(lambda pos: pos < 30, meanrecipientNumberInMails.values())))

plt.ylabel(u'Процент людей c таким же числом получателей')
plt.xlabel(u'Кол-во получателей')
plt.grid()
plt.plot(recipientsCcdf.keys(), recipientsCcdf.values(), 'bo')
plt.show()

# %% [markdown]
# По графику видно, что ~10% людей пишут 4 адресатам и более. Больше 50% людей пишут 2 адресатам.

# %% [markdown]
# ### Зависимость длины треда от кол-ва людей в треде

# %%
plt.loglog(meanrecipientNumberInMails.values(),meanPositionInTheThread.values(), 'bo')
plt.ylabel('Длина треда')
plt.xlabel('Кол-во людей в треде')
# Out:
# Text(0.5,0,'Кол-во людей в треде')

# %% [markdown]
# ## Данные

# %%
Reactions = map(lambda key: np.mean(senderDelays[key]) ,senderDelays.keys())

Positions = map(lambda key: np.mean(PositionInTheThread[key]) ,PositionInTheThread.keys())

RecipientsNumber = map(lambda key: np.mean(recipientNumberInMails[key]) ,recipientNumberInMails.keys())

MailSizes = map(lambda key: np.mean(mailSizes[key]) ,mailSizes.keys())

# %%
d = {
    'time to answer' : pd.Series(Reactions, index=senderDelays.keys()),
    'time to answer loc' : pd.Series(senderDelays_loc, index=senderDelays.keys()),
    'time to answer scale' : pd.Series(senderDelays_scale, index=senderDelays.keys()),
    'positions in the thread' : pd.Series(Positions, index=PositionInTheThread.keys()),
    'positions in the thread loc' : pd.Series(PositionInTheThread_loc, index=PositionInTheThread.keys()),
    'positions in the thread scale' : pd.Series(PositionInTheThread_scale, index=PositionInTheThread.keys()),
    'recipients number' : pd.Series(RecipientsNumber, index=recipientNumberInMails.keys()),
    'recipients number loc' : pd.Series(recipientNumberInMails_loc, index=recipientNumberInMails.keys()),
    'recipients number scale' : pd.Series(recipientNumberInMails_scale, index=recipientNumberInMails.keys()),
    'mail sizes' : pd.Series(MailSizes, index=mailSizes.keys()),
    'mail sizes loc' : pd.Series(mailSizes_loc, index=mailSizes.keys()),
    'mail sizes scale' : pd.Series(mailSizes_scale, index=mailSizes.keys())
    
}

# %%
df_final = pd.DataFrame(d)
df_final = df_final.dropna()

df_final.head()
# Out:
#                                                        mail sizes  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...  270269.369565
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...  105447.096667
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...  244517.368098
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...   35015.818182
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...  154965.780220
#
#                                                     mail sizes loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...        0.533532
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...        0.179329
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...        0.138090
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...        0.164313
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...        0.233031
#
#                                                     mail sizes scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...            9712.0
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...            4913.0
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...            3996.0
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...            5275.0
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...            6821.0
#
#                                                     positions in the thread  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                 1.000000
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                 3.476667
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                 4.276074
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                 1.388781
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                 5.601648
#
#                                                     positions in the thread loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                     0.402386
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                     0.402387
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                     0.482434
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                     0.271833
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                     0.110892
#
#                                                     positions in the thread scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                  -8.007409e-28
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                  -1.872527e-26
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                  -2.125198e-26
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                  -1.717449e-21
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                  -2.821068e-25
#
#                                                     recipients number  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...           4.304348
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...           1.803333
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...           2.245399
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...           2.075435
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...           2.601648
#
#                                                     recipients number loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...               0.579642
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...               0.110570
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...               0.224127
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...               0.255703
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...               0.333434
#
#                                                     recipients number scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                      1.0
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                      1.0
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                      1.0
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                      1.0
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                      1.0
#
#                                                     time to answer  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...     6515.133333
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...    11773.871429
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...    10065.417323
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...    28248.062992
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...    14076.529183
#
#                                                     time to answer loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...            0.553782
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...            0.711481
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...            0.244501
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...            0.383414
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...            0.247277
#
#                                                     time to answer scale
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...          8.100000e+01
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...         -6.484245e-21
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...          3.000000e+00
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...          3.000000e+00
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...         -1.617463e-22

# %%
plt.loglog(df_final['positions in the thread'], df_final['time to answer'], 'bo')
plt.ylabel('Время ответа')
plt.xlabel('Длина треда')
plt.grid(True)

# %% [markdown]
# Чем длиннее тред, тем быстрее отвечает человек. И чем меньше тред, тем медленнее отвечают на письма

# %%
plt.loglog(df_final['positions in the thread'], df_final['mail sizes'], 'bo')
plt.ylabel('Размер письма')
plt.xlabel('Длина треда')
plt.grid(True)

# %% [markdown]
# С ростом размера письма длина треда уменьшается

# %%
plt.loglog(df_final['mail sizes'], df_final['time to answer'], 'bo')
plt.ylabel('Время ответа')
plt.xlabel('Размер письма')
plt.grid(True)

# %% [markdown]
# С ростом размера писем время ответа на письмо увеличивается.

# %% [markdown]
# # CLUSTERS

# %% [markdown]
# Нормализуем данные перед кластеризацией

# %%
X = (df_final - df_final.mean()) / (df_final.max() - df_final.min())
X.head()
# Out:
#                                                     mail sizes  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...    0.096565
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...   -0.136534
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...    0.060145
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...   -0.236141
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...   -0.066503
#
#                                                     mail sizes loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...       -0.008475
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...       -0.008475
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...       -0.008475
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...       -0.008475
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...       -0.008475
#
#                                                     mail sizes scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...          0.008475
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...          0.008475
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...          0.008475
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...          0.008475
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...          0.008475
#
#                                                     positions in the thread  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                -0.058208
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                -0.016673
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                -0.003266
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                -0.051688
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                 0.018964
#
#                                                     positions in the thread loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                     0.011006
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                     0.011007
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                     0.075795
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                    -0.094660
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                    -0.224922
#
#                                                     positions in the thread scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                       0.008263
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                       0.008263
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                       0.008263
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                       0.008263
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                       0.008263
#
#                                                     recipients number  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...           0.587396
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...          -0.133826
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...          -0.006347
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...          -0.055360
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...           0.096385
#
#                                                     recipients number loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...               0.130985
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...              -0.329643
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...              -0.218131
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...              -0.187123
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...              -0.110792
#
#                                                     recipients number scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                 0.032139
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                 0.032139
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                 0.032139
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                 0.032139
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                 0.032139
#
#                                                     time to answer  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...       -0.111284
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...       -0.038899
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...       -0.062416
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...        0.187863
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...       -0.007204
#
#                                                     time to answer loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...            0.127164
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...            0.214457
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...           -0.044035
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...            0.032858
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...           -0.042499
#
#                                                     time to answer scale
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...             -0.008757
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...             -0.010087
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...             -0.010038
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...             -0.010038
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...             -0.010087

# %% [markdown]
# Посмотрим на разные методы кластеризации, в качестве метрики используем метрику silhoutte, так как нам заранее неизвестны метки объектов.

# %%
from sklearn import metrics
from sklearn import datasets
import pandas as pd
from sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation, SpectralClustering


algorithms = []
algorithms.append(KMeans(n_clusters=3))
algorithms.append(AffinityPropagation())
algorithms.append(SpectralClustering(n_clusters=3))
algorithms.append(AgglomerativeClustering(n_clusters=3))
algorithms.append(KMeans(n_clusters=4))
algorithms.append(SpectralClustering(n_clusters=4))
algorithms.append(AgglomerativeClustering(n_clusters=4))

data = []
for algo in algorithms:
    algo.fit(X)
    data.append(({
        'Silhouette': metrics.silhouette_score(X, algo.labels_)}))

results = pd.DataFrame(data=data, columns=['Silhouette'],
                       index=['K-means3', 'Affinity', 
                              'Spectral3', 'Agglomerative3', 'K-means4',
                              'Spectral4', 'Agglomerative4'])

# %%
results
# Out:
#                 Silhouette
# K-means3          0.258506
# Affinity          0.189943
# Spectral3         0.227503
# Agglomerative3    0.180893
# K-means4          0.239875
# Spectral4         0.193550
# Agglomerative4    0.173434

# %% [markdown]
# ## KMeans

# %%
range_n_clusters = range(3, 50)

# %%
def silhouetteScore(df, n_clusters = 2):
    est = KMeans(n_clusters=n_clusters)
    labels = est.fit_predict(df)
    return metrics.silhouette_score(df, labels)

# %%
scores = [silhouetteScore(X, n_clusters) for n_clusters in range_n_clusters]

plt.plot(range_n_clusters, scores)
plt.show()

# %%
for x,y in zip(range_n_clusters,scores):
    print (x,y)
# Out:
# 3 0.261607808855
# 4 0.254517598989
# 5 0.265434567831
# 6 0.188226334499
# 7 0.218553331315
# 8 0.203643504737
# 9 0.215125009425
# 10 0.226849904311
# 11 0.202821496773
# 12 0.216796123966
# 13 0.214152166945
# 14 0.218828144145
# 15 0.201427079428
# 16 0.206192905683
# 17 0.176777773399
# 18 0.16535192001
# 19 0.197795605209
# 20 0.204627465396
# 21 0.2044487502
# 22 0.207655991338
# 23 0.182942148528
# 24 0.206928405693
# 25 0.195182600748
# 26 0.221054140773
# 27 0.199046985418
# 28 0.195023798644
# 29 0.203512888311
# 30 0.210867423689
# 31 0.201732832133
# 32 0.19672960646
# 33 0.195030217489
# 34 0.207634005592
# 35 0.190640873196
# 36 0.196504239169
# 37 0.197550850603
# 38 0.180328883953
# 39 0.176441213282
# 40 0.185824403149
# 41 0.172843394294
# 42 0.192217179049
# 43 0.175995320306
# 44 0.185677631704
# 45 0.167979818888
# 46 0.165051148246
# 47 0.185812501751
# 48 0.154811139127
# 49 0.174199607593

# %% [markdown]
# Рассмотрим первый экстремум, 4 кластера

# %%
agg = KMeans(n_clusters=4)

agg.fit(X)
labels = agg.labels_

# %%
X['labels'] = labels

# %%
df_final['labels'] = labels

# %%
df_final.head()
# Out:
#                                                        mail sizes  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...  270269.369565
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...  105447.096667
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...  244517.368098
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...   35015.818182
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...  154965.780220
#
#                                                     mail sizes loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...        0.533532
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...        0.179329
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...        0.138090
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...        0.164313
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...        0.233031
#
#                                                     mail sizes scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...            9712.0
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...            4913.0
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...            3996.0
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...            5275.0
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...            6821.0
#
#                                                     positions in the thread  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                 1.000000
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                 3.476667
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                 4.276074
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                 1.388781
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                 5.601648
#
#                                                     positions in the thread loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                     0.402386
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                     0.402387
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                     0.482434
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                     0.271833
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                     0.110892
#
#                                                     positions in the thread scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                  -8.007409e-28
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                  -1.872527e-26
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                  -2.125198e-26
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                  -1.717449e-21
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                  -2.821068e-25
#
#                                                     recipients number  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...           4.304348
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...           1.803333
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...           2.245399
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...           2.075435
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...           2.601648
#
#                                                     recipients number loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...               0.579642
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...               0.110570
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...               0.224127
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...               0.255703
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...               0.333434
#
#                                                     recipients number scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                      1.0
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                      1.0
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                      1.0
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                      1.0
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                      1.0
#
#                                                     time to answer  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...     6515.133333
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...    11773.871429
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...    10065.417323
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...    28248.062992
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...    14076.529183
#
#                                                     time to answer loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...            0.553782
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...            0.711481
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...            0.244501
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...            0.383414
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...            0.247277
#
#                                                     time to answer scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...          8.100000e+01
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...         -6.484245e-21
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...          3.000000e+00
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...          3.000000e+00
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...         -1.617463e-22
#
#                                                     labels
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...       2
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...       1
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...       1
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...       1
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...       1

# %% [markdown]
# Для определения важности используемых признаков воспользуемся градиентным бустингом

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier()
clf.fit(X.iloc[:,0:12], X.iloc[:,12])
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]

# %%
feature_importance = clf.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.iloc[:,0:12].columns.values)
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(10, 10))
plt.clf()
    
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=30, azim=60)
ax.scatter(X.iloc[:,9], 
           X.iloc[:,6], 
           X.iloc[:,0], 
           c=labels.astype(np.float))

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel(u'Время ответа')
ax.set_ylabel(u'Кол-во получателей')
ax.set_zlabel(u'Размер писем')
plt.show()

# %%
plt.scatter(X.iloc[:, 6], 
            X.iloc[:, 0], 
            c=labels.astype(np.float))

plt.xlabel(u'Кол-во получателей')
plt.ylabel(u'Размер писем')
plt.show()

# %%
plt.scatter(X.iloc[:, 9], 
            X.iloc[:, 6], 
            c=labels.astype(np.float))

plt.xlabel(u'Время ответа')
plt.ylabel(u'Кол-во получателей')
plt.show()

# %%
X['labels'].value_counts()
# Out:
# 1    66
# 2    33
# 0    16
# 3     3
# Name: labels, dtype: int64

# %% [markdown]
# ### Кластер 1

# %%
df_cluster1 = df_final[df_final['labels'] == 1]

# %%
mail_distr = defaultdict(int)
scale = 200

for size in df_cluster1['mail sizes']:
    mail_distr[(size // scale) * scale] += 1

# %%
mail_cCDF = cCDF(mail_distr)
plt.loglog(mail_cCDF.keys(), mail_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Размер писем")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster1['mail sizes']), np.max(df_cluster1['mail sizes']))
# Out:
# Min, max: 10796.1904762 611170.938776

# %% [markdown]
# В первый кластер попали письма с большим размером данных от 100 до 611 Мб.

# %%
time = distribution(df_cluster1['time to answer'])

# %%
time_cCDF = cCDF(time)
plt.loglog(time_cCDF.keys(), time_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Время ответа(сек)")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster1['time to answer']), np.max(df_cluster1['time to answer']))
# Out:
# Min, max: 1229.75 28248.0629921

# %% [markdown]
# Время ответа на письма доходит от 20 минут до ~7 часов.

# %%
length = distribution(df_cluster1['positions in the thread'])

# %%
length_cCDF = cCDF(length)
plt.loglog(length_cCDF.keys(), length_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Длина треда")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster1['positions in the thread']), np.max(df_cluster1['positions in the thread']))
# Out:
# Min, max: 0.428571428571 19.1047619048

# %%
print (np.mean(df_cluster1['positions in the thread']))
# Out:
# 4.561665138103085

# %% [markdown]
# Кластер 2

# %%
df_cluster2 = df_final[df_final['labels'] == 2]

# %%
mail_distr = defaultdict(int)
scale = 200

for size in df_cluster2['mail sizes']:
    mail_distr[(size // scale) * scale] += 1

# %%
mail_cCDF = cCDF(mail_distr)
plt.loglog(mail_cCDF.keys(), mail_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Размер писем")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster2['mail sizes']), np.max(df_cluster2['mail sizes']))
# Out:
# Min, max: 75905.3152174 708568.22043

# %% [markdown]
# В этот кластер попали письма с большим размером данных от 75 до ~690 Мб. Cредний размер писем в этом кластере: ~380 Мб.

# %%
time = distribution(df_cluster2['time to answer'])

# %%
time_cCDF = cCDF(time)
plt.loglog(time_cCDF.keys(), time_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Время ответа(сек)")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster2['time to answer']), np.max(df_cluster2['time to answer']))
# Out:
# Min, max: 6515.13333333 42195.744186

# %% [markdown]
# Время ответа на письма доходит от 2 до ~11 часов. В среднем, пользователи в этом кластере отвечают в течение 7 часов.

# %%
length = distribution(df_cluster2['positions in the thread'])

# %%
length_cCDF = cCDF(length)
plt.loglog(length_cCDF.keys(), length_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Длина треда")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster2['positions in the thread']), np.max(df_cluster2['positions in the thread']))
# Out:
# Min, max: 1.0 10.7173913043

# %%
print (np.mean(df_cluster2['positions in the thread']))
# Out:
# 3.9341687989111924

# %% [markdown]
# Кластер 0

# %%
df_cluster0 = df_final[df_final['labels'] == 0]

# %%
mail_distr = defaultdict(int)
scale = 200

for size in df_cluster0['mail sizes']:
    mail_distr[(size // scale) * scale] += 1

# %%
mail_cCDF = cCDF(mail_distr)
plt.loglog(mail_cCDF.keys(), mail_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Размер писем")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster0['mail sizes']), np.max(df_cluster0['mail sizes']))
# Out:
# Min, max: 1476.35714286 370896.228261

# %% [markdown]
# В 0 кластер попали письма с большим размером данных от 1 до 300 Мб.

# %%
time = distribution(df_cluster0['time to answer'])

# %%
time_cCDF = cCDF(time)
plt.loglog(time_cCDF.keys(), time_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Время ответа(сек)")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster0['time to answer']), np.max(df_cluster0['time to answer']))
# Out:
# Min, max: 0.0 46414.0

# %% [markdown]
# Время ответа на письма доходит до ~12 часов.

# %%
length = distribution(df_cluster0['positions in the thread'])

# %%
length_cCDF = cCDF(length)
plt.loglog(length_cCDF.keys(), length_cCDF.values(), 'bo')
plt.ylabel(u"сCDF")
plt.xlabel(u"Длина треда")
plt.grid(True)
plt.show()

# %%
print ('Min, max:', np.min(df_cluster0['positions in the thread']), np.max(df_cluster0['positions in the thread']))
# Out:
# Min, max: 0.0454545454545 59.6736111111

# %%
print (np.mean(df_cluster0['positions in the thread']))
# Out:
# 5.764032105304574

# %% [markdown]
# Из первого и второго кластера можно сделать выводы, что те предположения, которые были построены по предварительному анализу данных верны. То есть действительно с ростом объема письма длина треда уменьшается, а время ответа на письмо увеличивается.

# %% [markdown]
# ## Посмотрим на другой экстремум, n = 7

# %%
X_7clusters = X[['time to answer' ,
    'positions in the thread' ,
    'recipients number',
    'mail sizes','time to answer loc','time to answer scale','positions in the thread loc','positions in the thread scale',
     'recipients number loc','recipients number scale', 'mail sizes loc', 'mail sizes scale']]
kmeans7 = KMeans(n_clusters=7)

kmeans7.fit(X_7clusters)
labels_7 = kmeans7.labels_
X_7clusters['labels'] = labels_7

# %% [markdown]
# Также определим важность признаков при 7 кластерах

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier()
clf.fit(X_7clusters.iloc[:,0:12], X_7clusters.iloc[:,12])
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]

# %%
feature_importance = clf.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X_7clusters.iloc[:,0:12].columns.values)
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %%
X_7clusters.head()
# Out:
#                                                     time to answer  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...       -0.111284
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...       -0.038899
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...       -0.062416
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...        0.187863
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...       -0.007204
#
#                                                     positions in the thread  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                -0.058208
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                -0.016673
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                -0.003266
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                -0.051688
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                 0.018964
#
#                                                     recipients number  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...           0.587396
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...          -0.133826
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...          -0.006347
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...          -0.055360
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...           0.096385
#
#                                                     mail sizes  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...    0.096565
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...   -0.136534
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...    0.060145
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...   -0.236141
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...   -0.066503
#
#                                                     time to answer loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...            0.127164
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...            0.214457
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...           -0.044035
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...            0.032858
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...           -0.042499
#
#                                                     time to answer scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...             -0.008757
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...             -0.010087
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...             -0.010038
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...             -0.010038
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...             -0.010087
#
#                                                     positions in the thread loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                     0.011006
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                     0.011007
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                     0.075795
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                    -0.094660
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                    -0.224922
#
#                                                     positions in the thread scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                       0.008263
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                       0.008263
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                       0.008263
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                       0.008263
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                       0.008263
#
#                                                     recipients number loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...               0.130985
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...              -0.329643
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...              -0.218131
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...              -0.187123
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...              -0.110792
#
#                                                     recipients number scale  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...                 0.032139
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...                 0.032139
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...                 0.032139
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...                 0.032139
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...                 0.032139
#
#                                                     mail sizes loc  \
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...       -0.008475
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...       -0.008475
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...       -0.008475
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...       -0.008475
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...       -0.008475
#
#                                                     mail sizes scale  labels
# 0814f7ee8faf3c748540baf83611bc69@8d192ad005fa78...          0.008475       5
# 08cc8fd0ca7f2d9959c7e383952f7a2b@8d192ad005fa78...          0.008475       6
# 0cd4d12b78f52b88563a133f99dbd300@8d192ad005fa78...          0.008475       4
# 0d5a5ecb4e0af8144a30e899b294bf45@8d192ad005fa78...          0.008475       6
# 101a5b9ab6c81dd9f6f461423bb2f6b8@8d192ad005fa78...          0.008475       1

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(10, 10))
plt.clf()
    
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=30, azim=60)
ax.scatter(X_7clusters.iloc[:,2], 
           X_7clusters.iloc[:,10], 
           X_7clusters.iloc[:,6], 
           c=labels.astype(np.float))

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel(u'Длина треда во время отправки')
ax.set_ylabel(u'Размер писем loc')
ax.set_zlabel(u'Позиция в треде loc')
plt.show()

# %%
plt.scatter(X.iloc[:, 6], 
            X.iloc[:, 10], 
            c=labels.astype(np.float))

plt.xlabel(u'Позиция в треде  loc')
plt.ylabel(u'Размер писем loc')
plt.show()

# %% [markdown]
# Как видим, выделяются основные 4 класса, поэтому будем рассматривать первый экстремум.
